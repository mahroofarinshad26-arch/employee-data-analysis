# %%
import pandas as pd
df=pd.read_csv("myexcel - myexcel.csv.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
import pandas as pd
import numpy as np

df['height'] = np.random.randint(150,181, size=len(df))
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary  height
# 0              Texas  7730337.0     151
# 1          Marquette  6796117.0     165
# 2  Boston University        NaN     171
# 3      Georgia State  1148640.0     170
# 4                NaN  5000000.0     175

# %%
team_count = df['Team'].value_counts()
percentage = (team_count/len(df)) * 100
print(percentage)
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
team_count.plot(kind='bar')
plt.title("Employee Distribution by Team")
plt.xlabel("Team")
plt.ylabel("Count")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
Position_Count = df['Position'].value_counts()
Position_Count.plot(kind="bar",color="red")
plt.title("Employee by Position",size=16)
plt.xlabel("Position",size=12)
plt.ylabel("Count",size=12)
plt.xticks(rotation=0)
    

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.hist(df["Age"], bins=10)
plt.title("Age Distribution", size=16)
plt.xlabel("Age", size=12)
plt.ylabel("Frequancy", size=12)

plt.show()

# %%
print(df['Age'].mode())
# Out:
# 0    24
# Name: Age, dtype: int64

# %%
team_salary = df.groupby('Team')['Salary'].sum()
print(team_salary)
# Out:
# Team
# Atlanta Hawks              72902950.0
# Boston Celtics             58541068.0
# Brooklyn Nets              52528475.0
# Charlotte Hornets          78340920.0
# Chicago Bulls              86783378.0
# Cleveland Cavaliers       106988689.0
# Dallas Mavericks           71198732.0
# Denver Nuggets             60121930.0
# Detroit Pistons            67168263.0
# Golden State Warriors      88868997.0
# Houston Rockets            75283021.0
# Indiana Pacers             66751826.0
# Los Angeles Clippers       94854640.0
# Los Angeles Lakers         71770431.0
# Memphis Grizzlies          76550880.0
# Miami Heat                 82515673.0
# Milwaukee Bucks            69603517.0
# Minnesota Timberwolves     59709697.0
# New Orleans Pelicans       82750774.0
# New York Knicks            73303898.0
# Oklahoma City Thunder      93765298.0
# Orlando Magic              60161470.0
# Philadelphia 76ers         30992894.0
# Phoenix Suns               63445135.0
# ...

# %%
Position_Salary = df.groupby('Position')['Salary'].sum()
print(Position_Salary)
# Out:
# Position
# C     466377332.0
# PF    442560850.0
# PG    446848971.0
# SF    408020976.0
# SG    396976258.0
# Name: Salary, dtype: float64

# %%
team_salary.plot(kind='bar')
plt.title("Salary Expenditure by Team")
plt.show()

# %%
correlation = df['Age'].corr(df['Salary'])
print("Correlation:", correlation)
# Out:
# Correlation: 0.21400941226570974

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(x='Age', y='Salary', data=df)

plt.title("Age vs Salary Relationship",size=16)
plt.xlabel("Age",size=14)
plt.ylabel("Salary",size=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Data Insights
#
#
# * Most employees belong to the New Orleans Pelicans team.
# * The most common position is manager.
# * Majority of Employees are aged between 25-30.
# * Sales team has the highest salary expenditure.
# * There is s slight positive correlation betwenn age and salary.
# * As age increases salary increases.
